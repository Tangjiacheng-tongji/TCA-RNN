# %%
import tensortools as tt
import numpy as np
import matplotlib.pyplot as plt

# %%
test_result=np.loadtxt("temp.txt").reshape((400,49,100))#750 trails，100 neurons and 49 time points

# %%
A=tt.Ensemble(fit_method='cp_als')

# %%
A.fit(test_result,ranks=range(1,6),replicates=3)
# Out:
# Rank-1 models:  min obj, 0.13;  max obj, 0.13;  time to fit, 0.3s
# Rank-2 models:  min obj, 0.09;  max obj, 0.09;  time to fit, 3.5s
# Rank-3 models:  min obj, 0.07;  max obj, 0.08;  time to fit, 3.2s
# Rank-4 models:  min obj, 0.06;  max obj, 0.06;  time to fit, 4.6s
# Rank-5 models:  min obj, 0.04;  max obj, 0.06;  time to fit, 5.2s

# %%
plt.figure()
tt.plot_objective(A)
plt.show()

# %%
plt.figure()
tt.plot_similarity(A)
plt.show()

# %%
'''for i in range(1,6):
    U=A.results[i][0].factors
    fig=tt.plot_factors(U,plots=['scatter','bar','line'],scatter_kw={'color': 'green'},line_kw={'color': 'red'},bar_kw={'color':'blue'})'''
# Out:
# "for i in range(1,6):\n    U=A.results[i][0].factors\n    fig=tt.plot_factors(U,plots=['scatter','bar','line'],scatter_kw={'color': 'green'},line_kw={'color': 'red'},bar_kw={'color':'blue'})"

# %%
U=A.results[3][0].factors
fig=tt.plot_factors(U,plots=['scatter','line','bar'],scatter_kw={'color': 'green'},line_kw={'color': 'red'},bar_kw={'color':'blue'})

# %%
#Check which neuron is classified first, and then determine the rank to be sorted
#fig=tt.plot_factors(U,sort=[2,0],plots=['scatter','line','bar'],scatter_kw={'color': 'green'},line_kw={'color': 'red'},bar_kw={'color':'blue'})

# %%
for i in range(len(U.factors)):
    np.savetxt("components"+str(i)+".txt",U.factors[i])
    print(str(i))
# Out:
# 0
# 1
# 2
